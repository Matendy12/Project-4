# %%
# Install Python module spotipy
# !pip install spotipy

# %%
# Import our dependencies
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials 
client_id = "094d3a865ba64930bbcc595834c916ab"
client_secret = "979848051ce440558695f0ef9e857e40"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

import os
import numpy as np
import pandas as pd

import seaborn as sns
import plotly.express as px 
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import euclidean_distances
from scipy.spatial.distance import cdist

import warnings
warnings.filterwarnings("ignore")

# %%
# Import and read csv file
import pandas
csvfile = pandas.read_csv('artists.csv')

# %%
# Spotify most streamed artists of all time
df = pandas.read_csv('artists.csv')
df.head(10)
# Out:
#           Artist   Streams   Daily   As lead      Solo As feature
# 0          Drake  85,041.3  50.775  57,252.6  32,681.6   27,788.7
# 1      Bad Bunny  67,533.0  44.820  40,969.6  23,073.0   26,563.4
# 2   Taylor Swift  57,859.0  85.793  55,566.7  50,425.7    2,292.4
# 3     The Weeknd  53,665.2  44.437  42,673.3  31,164.2   10,991.9
# 4     Ed Sheeran  47,907.7  17.506  42,767.9  33,917.0    5,139.8
# 5  Justin Bieber  47,525.7  18.868  27,988.0  17,183.9   19,537.7
# 6         Eminem  42,029.0  20.175  35,475.8  21,576.7    6,553.2
# 7  Ariana Grande  40,111.0  17.158  33,219.8  23,307.3    6,891.2
# 8       J Balvin  38,774.8  11.784  17,450.7   5,699.8   21,324.2
# 9    Post Malone  38,002.7  21.095  34,494.0  18,943.9    3,508.6

# %%
# Import and read csv file
import pandas
CSVfile = pandas.read_csv('listeners.csv')

# %%
# Spotify top artists by monthly listeners
DF = pandas.read_csv('listeners.csv')
DF.head(10)
# Out:
#           Artist    Listeners Daily Trend  Peak  PkListeners
# 0     The Weeknd  107,592,328    -138,880     1  113,034,886
# 1   Taylor Swift  101,003,302         889     2  101,003,302
# 2     Ed Sheeran   76,475,126     -68,137     2   87,934,910
# 3       Dua Lipa   76,421,916     -71,356     4   77,778,397
# 4      Bad Bunny   76,162,057    -199,052     3   83,950,570
# 5        Rihanna   75,784,389     116,405     2   80,958,750
# 6          Drake   75,371,611     -67,013     6   76,391,086
# 7  Justin Bieber   72,623,228      34,540     6   75,467,229
# 8  Billie Eilish   71,793,820     -72,877     8   72,368,528
# 9    Miley Cyrus   71,277,599      71,089     2   84,140,935

# %%
# Import and read csv file
import pandas
Csvfile = pandas.read_csv('Spotify most streamed.csv')

# %%
# Spotify most streamed songs
Df = pandas.read_csv('Spotify most streamed.csv')
Df.head(10)
# Out:
#                     Artist and Title        Streams      Daily
# 0       The Weeknd - Blinding Lights  3,783,983,806  1,736,378
# 1          Ed Sheeran - Shape of You  3,616,649,759  1,135,140
# 2  Lewis Capaldi - Someone You Loved  2,958,875,491  1,522,093
# 3            Post Malone - Sunflower  2,898,311,408  1,871,177
# 4         Tones And I - Dance Monkey  2,896,024,418    666,818
# 5                  Drake - One Dance  2,770,548,672  1,461,772
# 6             Post Malone - rockstar  2,763,808,309    821,331
# 7               The Kid LAROI - STAY  2,738,183,590  1,490,471
# 8               The Weeknd - Starboy  2,658,550,411  2,205,639
# 9         Imagine Dragons - Believer  2,654,895,028  1,346,642
